  1   8   0   8   8   6  13 
  2  12   8   8   8   0   3 
  1  16   0  16   8   6  13 
144
  1   0   0   0  12   6  13 
  2   4   8   8   8   0   3 
  1   8   0   8   8   6  13 
136
  2   5   6  10  12   6  13 
138
  2   5   6  10  12   6  13 
  1   0  -4   0  12   6  13 
138
  2   5   6  10  12   6  13 
  1  10  -4  10  12   6  13 
138
  1   0   0   0  12   6  13 
  2   5   6  10  12   1   3 
136
  2   4   9   8   6   0   5 
  2   4   3   8   6   4   9 
136
  1   0  12   8  12   6  13 
  1   4   0   4  16   6  13 
136
  1   8   0   8  12   6  13 
  2   4   4   8   8   4   7 
  1   0   4   0  12   6  13 
136
  1   0  12   4   0   6  13 
  1   4   0   8  12   6  13 
136
  1   0  12   4   0   6  13 
  1   4   0   8  12   6  13 
  1   8  12  12   0   6  13 
  1  12   0  16  12   6  13 
144
  1   0  12   8   0   6  13 
  1   0   0   8  12   6  13 
136
  1   0  12   4   0   6  13 
  1   4   0   8  12   6  13 
  2   1   0   6   8   6   7 
136
  1   0   0   8   0   6  13 
  1   0  12   8  12   6  13 
  1   0   0   8  12   6  13 
136
  2   8   6   8  12   4   5 
  2   0   6   8   8   0   1 
  2   0  14   8   8   6   7 
  2   8  14   8  12   2   3 
136
  1   1   1   1  21   6  13 
130
  2   0   6   8  12   6   7 
  2   8   6   8   8   2   3 
  2   8  14   8   8   4   5 
  2   0  14   8  12   0   1 
136
  2   3  12   6   4   0   3 
  2   9  12   6   4   4   7 
140
  1   0  10   6  20   6  13 
  1   0   0  12  20   6  13 
  1   6   0  12  10   6  13 
140
'''

# %% [markdown]
# # Convert the arc font format

# %%
# all glyphs
all_bs = bytes()
glyph_props = []

# one glyph as bytes blob
bs = bytes()
ce = CoordinateEncoder()
bb_x = MinMax()
bb_y = MinMax()
start_index = 0

for ll in dat.splitlines():
    l = ll.split()
    
    # glyph width is a line with one number only. It's the end of the glyph
    if len(l) == 1:
        bs += (T_END << 4).to_bytes()
        all_bs += bs
        glyph_props.append({
            "start_index": start_index,
            "adv_w": (int(l[0]) & 0x7F) + 3,
#             "box_w": bb_x.get_max() - bb_x.get_min(),
#             "box_h": bb_y.get_max() - bb_y.get_min(),
        })
        
        start_index += len(bs)
        
        # reset internal states for the next glyph
        bs = bytes()
        ce = CoordinateEncoder()
        bb_x.reset()
        bb_y.reset()
        continue
    
    dats = [int(d) for d in l]
    t, a_x, a_y, b_x, b_y, fo, lo = dats
    
    # t indicates the type
    if t == 1:  # line
        bs += ce.encode([a_x, a_y], T_GOTO << 4)
        bb_x.add(a_x)
        bb_y.add(a_y)
        bs += ce.encode([b_x, b_y], T_LINETO << 4)
        bb_x.add(b_x)
        bb_y.add(b_y)
    elif t == 2:  # arc
        bs += ce.encode([a_x, a_y], T_ARC << 4)
        bs += b_x.to_bytes()
        bs += b_y.to_bytes()
        bs += (fo << 4 | lo).to_bytes()
        bb_x.add(a_x - b_x)
        bb_x.add(a_x + b_x)
        bb_y.add(a_y - b_y)
        bb_y.add(a_y + b_y)
    else:
        print("HUH!!")

# %% [markdown]
# # Generate source code file

# %%
f = None
# f = open("../src/font_data/arc.c", "w")

print(f'''\
// -----------------------------------
//  SCTV scope clock font
// -----------------------------------
// Nice simplistic font using arcs and line segments.
// Originally appeared in the scope clock from nixiebunny.
// https://github.com/nixiebunny/SCTVcode/blob/main/SCTVcode/b_font.ino

static const uint8_t glyphs_arc[{len(all_bs)}] = {{''', file=f)
print_table(all_bs, f=f)

print(f'''\
// GLYPH DESCRIPTION
static const glyph_dsc_t glyph_dsc_arc[{len(glyph_props)}] = {{''', file=f)
for line in glyph_props:
    print("    {" + ", ".join([f'.{k} = {v:4d}' for k, v in line.items()]) + "},", file=f)
print("};", file=f)

print(f'''
const font_t f_arc = {{
    .n_glyphs = {len(glyph_props)},
    .glyphs = glyphs_arc,
    .glyph_dsc = glyph_dsc_arc,
}};
''', file=f)

# f.close()
# print('wrote', f.name)
# Out:
# // -----------------------------------
# //  SCTV scope clock font
# // -----------------------------------
# // Nice simplistic font using arcs and line segments.
# // Originally appeared in the scope clock from nixiebunny.
# // https://github.com/nixiebunny/SCTVcode/blob/main/SCTVcode/b_font.ino
#
# static const uint8_t glyphs_arc[1263] = {
# 240, 15,  1,  6, 26, 14, 66, 19,  2,  2,109,240, 10, 12, 26,  8,  7,  6,  8, 26,  8,240, 15,  2,
#   4, 31,  2, 16,  7,  3, 16, 31,  2, 16,  3,  9, 11, 21, 10, 11,  9,  6, 21, 10,240, 79,  5,  8,
#  10,  8, 73, 74,  8, 10,  8,  5,  2, 16, 26, 24,240, 79,  3, 17,  6,  6,109, 71,  6, 14,  6,  6,
# 109,  3,  9,  3, 31, 12, 20,240, 79,  4, 15,  8, 10,108, 66, 10,  8, 10, 37, 74,  3, 16, 16,103,
#  11,  3,  4, 23, 10, 12,240, 79,  3, 19,  2,  2,109, 65,  3,  8, 12,103,240, 79,  4, 10,  8, 20,
#  37,240, 74, 10,  8, 20,105,240, 10, 10, 21, 12,  3, 10,  6, 31,  8, 12,  1,  8, 23,  8, 12,240,
#  10, 10, 21, 12,  3,  6,  6, 26, 12,240, 79,  3,  1,  2,  2,109, 65,  3,  8, 12,103,240, 10, 10,
#  21, 12,240, 79,  1,  1,  2,  2,109,240,  0, 31, 12, 20,240, 79,  6, 10, 12, 20,109,240,  5,  7,
#  26, 20,  3,  4,  4, 31,  4,  4,240, 79,  6, 14, 12, 12,107, 66, 14, 12, 16, 35,  1,  6, 21, 12,
# 240, 79,  6,  6, 12, 12, 89, 11,  5, 14, 21, 10,  3,  5,  8, 31,  5,  8,240,  5,  8, 26, 20,  3,
#   8, 14, 21, 12,  1, 12, 31,  8, 14,240, 79,  6,  6, 12, 12, 90, 11,  4,  4, 31,  2, 10,  0, 21,
#   8,240, 79,  6,  6, 12, 12,109, 11,  5,  4, 31,  7, 10,240,  0, 31, 12, 20,  1, 12, 21, 12,240,
#  79,  6,  6, 12, 12,109, 74, 10,  8,  8,109,240, 79,  6, 14, 12, 12,109,  3,  2, 14, 31,  7, 10,
# 240, 79,  2,  6,  4,  4,109, 74,  8,  4,  4,109,240, 79,  3, 14,  2,  2,109, 66,  8,  2,  2,109,
#  65,  3,  8, 12,103,240, 10, 10, 31, 12,  8,  3, 12,  8, 23, 12,  8,240, 10, 13, 21, 12,  3, 12,
# 240, 79,  5,  6, 10, 12,109,  7,  5,  6, 26, 12, 67,  5, 12, 10, 12, 87,240, 79,  4,  8,  8,  8,
#   3,  3,  4,  8, 26, 20,  7,  8, 20, 26,  8,240, 79,  1, 16,  2,  2,109,  2, 16, 26, 12,240, 79,
#   6, 16,  2,  2,109,  2, 16, 26, 12, 67,  3, 12,  6,  8, 87,240,  0, 26, 20,  2, 16, 31,  8,  8,
#   3,  7,  6, 23,  6,  6,240,  5,  1, 26, 20,240,  0, 26, 12, 71,  4,  4,  8,  8,  3,  7,  4,  8,
#  26,  8, 69,  4,  8,  8,  3,  7,  4,  8, 26,  8,240,  0, 26, 12, 71,  4,  4,  8,  8,  3,  7,  4,
#   8, 26,  8,240, 79,  5,  6, 10, 12,109,240, 79,  5,  6, 10, 12,109,  3,  5, 10, 26, 16,240, 79,
#   5,  6, 10, 12,109,  7,  5, 10, 26, 16,240,  0, 26, 12, 71,  5,  6, 10, 12, 19,240, 79,  4,  9,
#   8,  6,  5, 66,  6,  8,  6, 73,240, 10, 12, 21,  8,  3,  4, 12, 26, 16,240,  5,  8, 26, 12, 67,
#   4,  8,  8,  8, 71,  1,  4, 26,  8,240, 10, 12, 23,  4, 12,  0, 31,  4, 12,240, 10, 12, 23,  4,
#  12,  0, 31,  4, 12,  0, 23,  4, 12,  0, 31,  4, 12,240, 10, 12, 23,  8, 12,  1,  8, 31,  8, 12,
# 240, 10, 12, 23,  4, 12,  0, 31,  4, 12, 67,  7, 12,  6,  8,103,240,  0, 21,  8, 11,  8, 12, 21,
#   8,  3,  8, 12, 31,  8, 12,240, 79,  8,  6,  8, 12, 69, 65,  8,  8,  8,  1, 74,  8,  8,  8,103,
#  69,  8,  8, 12, 35,240, 15,  1,  1, 26, 20,240, 74,  6,  8, 12,103, 69,  8,  8,  8, 35, 74,  8,
#   8,  8, 69, 65,  8,  8, 12,  1,240, 79,  3, 12,  6,  4,  3, 69,  6,  6,  4, 71,240, 10, 10, 31,
#   6, 10,  3,  6, 20, 31, 12, 20,  3,  6, 20, 31,  6, 10,240
# };
#
# // GLYPH DESCRIPTION
# static const glyph_dsc_t glyph_dsc_arc[96] = {
#     {.start_index =    0, .adv_w =    9},
#     {.start_index =    1, .adv_w =    5},
#     {.start_index =   12, .adv_w =    9},
#     {.start_index =   22, .adv_w =   15},
#     {.start_index =   45, .adv_w =   13},
#     {.start_index =   61, .adv_w =   15},
#     {.start_index =   80, .adv_w =   15},
#     {.start_index =  103, .adv_w =    7},
#     {.start_index =  115, .adv_w =    7},
#     {.start_index =  122, .adv_w =    7},
#     {.start_index =  128, .adv_w =   15},
#     {.start_index =  144, .adv_w =   15},
#     {.start_index =  154, .adv_w =    7},
#     {.start_index =  166, .adv_w =   15},
#     {.start_index =  171, .adv_w =    5},
#     {.start_index =  178, .adv_w =   15},
#     {.start_index =  183, .adv_w =   15},
#     {.start_index =  190, .adv_w =   15},
#     {.start_index =  201, .adv_w =   15},
#     {.start_index =  217, .adv_w =   15},
#     {.start_index =  235, .adv_w =   15},
#     {.start_index =  250, .adv_w =   15},
#     {.start_index =  266, .adv_w =   15},
#     {.start_index =  279, .adv_w =   15},
#     {.start_index =  288, .adv_w =   15},
#     {.start_index =  300, .adv_w =   15},
#     {.start_index =  313, .adv_w =    7},
#     {.start_index =  325, .adv_w =    7},
#     {.start_index =  342, .adv_w =   15},
#     {.start_index =  354, .adv_w =   15},
#     {.start_index =  364, .adv_w =   15},
#     {.start_index =  376, .adv_w =   13},
#     {.start_index =  393, .adv_w =   15},
#     {.start_index =  409, .adv_w =   15},
#     {.start_index =  423, .adv_w =   15},
#     {.start_index =  451, .adv_w =   15},
#     {.start_index =  458, .adv_w =   15},
#     {.start_index =  476, .adv_w =   15},
#     {.start_index =  494, .adv_w =   15},
#     {.start_index =  507, .adv_w =   15},
#     {.start_index =  523, .adv_w =   15},
#     {.start_index =  537, .adv_w =    7},
#     {.start_index =  552, .adv_w =   15},
#     {.start_index =  564, .adv_w =   15},
#     {.start_index =  579, .adv_w =   15},
#     {.start_index =  587, .adv_w =   15},
#     {.start_index =  605, .adv_w =   15},
#     {.start_index =  619, .adv_w =   15},
#     {.start_index =  626, .adv_w =   15},
#     {.start_index =  644, .adv_w =   15},
#     {.start_index =  657, .adv_w =   15},
#     {.start_index =  681, .adv_w =   15},
#     {.start_index =  693, .adv_w =   15},
#     {.start_index =  702, .adv_w =   15},
#     {.start_index =  718, .adv_w =   15},
#     {.start_index =  728, .adv_w =   15},
#     {.start_index =  747, .adv_w =   15},
#     {.start_index =  758, .adv_w =   15},
#     {.start_index =  773, .adv_w =   15},
#     {.start_index =  788, .adv_w =    7},
#     {.start_index =  801, .adv_w =   15},
#     {.start_index =  807, .adv_w =    7},
#     {.start_index =  822, .adv_w =   15},
#     {.start_index =  832, .adv_w =   15},
#     {.start_index =  836, .adv_w =    7},
#     {.start_index =  842, .adv_w =   13},
#     {.start_index =  854, .adv_w =   13},
#     {.start_index =  866, .adv_w =   11},
#     {.start_index =  873, .adv_w =   13},
#     {.start_index =  885, .adv_w =   13},
#     {.start_index =  896, .adv_w =   13},
#     {.start_index =  913, .adv_w =   13},
#     {.start_index =  931, .adv_w =   11},
#     {.start_index =  948, .adv_w =    5},
#     {.start_index =  959, .adv_w =   11},
#     {.start_index =  976, .adv_w =   11},
#     {.start_index =  991, .adv_w =    5},
#     {.start_index =  996, .adv_w =   19},
#     {.start_index = 1021, .adv_w =   11},
#     {.start_index = 1036, .adv_w =   13},
#     {.start_index = 1043, .adv_w =   13},
#     {.start_index = 1055, .adv_w =   13},
#     {.start_index = 1067, .adv_w =   11},
#     {.start_index = 1077, .adv_w =   11},
#     {.start_index = 1089, .adv_w =   11},
#     {.start_index = 1099, .adv_w =   11},
#     {.start_index = 1114, .adv_w =   11},
#     {.start_index = 1124, .adv_w =   19},
#     {.start_index = 1142, .adv_w =   11},
#     {.start_index = 1153, .adv_w =   11},
#     {.start_index = 1169, .adv_w =   11},
#     {.start_index = 1184, .adv_w =   11},
#     {.start_index = 1206, .adv_w =    5},
#     {.start_index = 1212, .adv_w =   11},
#     {.start_index = 1233, .adv_w =   15},
#     {.start_index = 1245, .adv_w =   15},
# };
#
# const font_t f_arc = {
#     .n_glyphs = 96,
#     .glyphs = glyphs_arc,
#     .glyph_dsc = glyph_dsc_arc,
# };
