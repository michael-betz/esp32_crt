# %%
# %pylab notebook
from fontTools import ttLib
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
tt = ttLib.TTFont("./RoyalBrand-mL4pj.ttf") # Load an existing font file
tt.ensureDecompiled()

# %%
tt.tables
# Out:
# {'GlyphOrder': <fontTools.ttLib.ttFont.GlyphOrder at 0x7fe24c123890>,
#  'head': <'head' table at 7fe24c143a90>,
#  'hhea': <'hhea' table at 7fe24cf2bbd0>,
#  'maxp': <'maxp' table at 7fe24c0bbc90>,
#  'OS/2': <'OS/2' table at 7fe24c0bbd90>,
#  'hmtx': <'hmtx' table at 7fe24c11f050>,
#  'post': <'post' table at 7fe24c0bbd50>,
#  'cmap': <'cmap' table at 7fe24c14d650>,
#  'fpgm': <'fpgm' table at 7fe267fcad50>,
#  'prep': <'prep' table at 7fe24cf50c10>,
#  'cvt ': <'cvt ' table at 7fe24cf5d8d0>,
#  'loca': <'loca' table at 7fe24c155990>,
#  'glyf': <'glyf' table at 7fe24c0c5a50>,
#  'name': <'name' table at 7fe24c0f7ed0>,
#  'gasp': <'gasp' table at 7fe24c174610>,
#  'GDEF': <'GDEF' table at 7fe24c0fc6d0>,
#  'GPOS': <'GPOS' table at 7fe24c0bbbd0>,
#  'GSUB': <'GSUB' table at 7fe24c11ee90>}

# %%
gs = tt['glyf'].glyphs
g = gs['k']

# %%
g.coordinates?

# %%
g.flags?

# %%
close()
plot([c[0] for c in g.coordinates], [c[1] for c in g.coordinates], '.-')
axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-84.05000000000001, 885.05, -85.45, 1926.45)

# %%
from fontTools.pens.boundsPen import BoundsPen
from fontTools.pens.basePen import BasePen

# %%
gs = tt.getGlyphSet()

# %%
bp = BoundsPen(gs)
gs["k"].draw(bp)
bp.bounds
# Out:
# (-40, 6, 841, 1835)

# %%
class MyPen(BasePen):
    def _lineTo(self, pt):
        print('lineTo', self.last_point, pt)
        self.last_point = pt
    
    def _moveTo(self, pt):
        print('moveTo', pt)
        self.last_point = pt
        
#     def _curveToOne(self, pt1, pt2, pt3):
#         print('curveToOne', pt1, pt2, pt3)
        
    def _qCurveToOne(self, pt1, pt2):
        pt0 = self.last_point
        print('qCurveToOne', pt0, pt1, pt2)
        self.last_point = pt2

mp = MyPen(gs)

# %%
gs["k"].draw(mp)
# Out:
# moveTo (107, 6)
# qCurveToOne (107, 6) (94, 6) (75.0, 14.5)
# qCurveToOne (75.0, 14.5) (56, 23) (41, 51)
# qCurveToOne (41, 51) (35, 62) (29, 83)
# qCurveToOne (29, 83) (-12, 210) (-26.0, 383.5)
# qCurveToOne (-26.0, 383.5) (-40, 557) (-40, 709)
# qCurveToOne (-40, 709) (-40, 931) (-24.0, 1134.5)
# qCurveToOne (-24.0, 1134.5) (-8, 1338) (15.0, 1503.5)
# qCurveToOne (15.0, 1503.5) (38, 1669) (61, 1782)
# qCurveToOne (61, 1782) (66, 1806) (84.0, 1820.5)
# qCurveToOne (84.0, 1820.5) (102, 1835) (125, 1835)
# qCurveToOne (125, 1835) (151, 1835) (171.0, 1816.5)
# qCurveToOne (171.0, 1816.5) (191, 1798) (191, 1769)
# qCurveToOne (191, 1769) (191, 1763) (190, 1756)
# qCurveToOne (190, 1756) (145, 1528) (118.5, 1247.0)
# qCurveToOne (118.5, 1247.0) (92, 966) (92, 712)
# qCurveToOne (92, 712) (92, 643) (94, 579)
# qCurveToOne (94, 579) (124, 672) (157.0, 730.0)
# qCurveToOne (157.0, 730.0) (190, 788) (223.5, 819.0)
# qCurveToOne (223.5, 819.0) (257, 850) (287.5, 861.0)
# ...
