# %%
# %pylab notebook
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
x_, y_ = 0, 0

def d(x, y, mult=0.25 / 4):
  global x_, y_
  plot(x_, y_, 'or')
  distx = x - x_
  disty = y - y_
  dist = sqrt(distx * distx + disty * disty)
  print(f"line from {x_:3.1f}, {y_:3.1f} to {x:3.1f}, {y:3.1f}, dist: {dist:.3f}");

  n = dist * mult
  n = int(n + 0.5)
  if n <= 0:
    return
  dx = distx / n
  dy = disty / n
  for i in range(n):
    x_ += dx
    y_ += dy
    plot(x_, y_, '.k')
    print(f'{x_:3.1f}, {y_:3.1f}')

d(0, 0)
axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# line from 0.0, 0.0 to 0.0, 0.0, dist: 0.000
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
d(-1000,-1000,  0)
d(-1000, 1000)
d( 1000, 1000)
d( 1000,-1000)
d(-1000,-1000)
d( -100, -100,  0)
d(  100,  100)
d( -100,  100,  0)
d(  100, -100)
# Out:
# line from 0.0, 0.0 to -1000.0, -1000.0, dist: 1414.214
# line from 0.0, 0.0 to -1000.0, 1000.0, dist: 1414.214
# -11.4, 11.4
# -22.7, 22.7
# -34.1, 34.1
# -45.5, 45.5
# -56.8, 56.8
# -68.2, 68.2
# -79.5, 79.5
# -90.9, 90.9
# -102.3, 102.3
# -113.6, 113.6
# -125.0, 125.0
# -136.4, 136.4
# -147.7, 147.7
# -159.1, 159.1
# -170.5, 170.5
# -181.8, 181.8
# -193.2, 193.2
# -204.5, 204.5
# -215.9, 215.9
# -227.3, 227.3
# -238.6, 238.6
# -250.0, 250.0
# -261.4, 261.4
# -272.7, 272.7
# -284.1, 284.1
# -295.5, 295.5
# -306.8, 306.8
# -318.2, 318.2
# -329.5, 329.5
# -340.9, 340.9
# -352.3, 352.3
# -363.6, 363.6
# -375.0, 375.0
# -386.4, 386.4
# -397.7, 397.7
# -409.1, 409.1
# -420.5, 420.5
# -431.8, 431.8
# -443.2, 443.2
# -454.5, 454.5
# -465.9, 465.9
# -477.3, 477.3
# -488.6, 488.6
# -500.0, 500.0
# -511.4, 511.4
# -522.7, 522.7
# -534.1, 534.1
# -545.5, 545.5
# -556.8, 556.8
# -568.2, 568.2
# -579.5, 579.5
# -590.9, 590.9
# -602.3, 602.3
# -613.6, 613.6
# -625.0, 625.0
# -636.4, 636.4
# ...
