# %%
# %pylab notebook
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
x_, y_ = 0, 0

def d(x, y, mult=0.25 / 4):
  global x_, y_
  plot(x_, y_, 'or')
  distx = x - x_
  disty = y - y_
  dist = sqrt(distx * distx + disty * disty)
  print(f"line from {x_:3.1f}, {y_:3.1f} to {x:3.1f}, {y:3.1f}, dist: {dist:.3f}");

  n = dist * mult
  n = int(n + 0.5)
  if n <= 0:
    return
  dx = distx / n
  dy = disty / n
  for i in range(n):
    x_ += dx
    y_ += dy
    plot(x_, y_, '.k')
    print(f'{x_:3.1f}, {y_:3.1f}')

d(0, 0)
axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# line from 0.0, 0.0 to 0.0, 0.0, dist: 0.000
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
d(0, 50)
d(50, 50)
d(50, 0)
d(0, 0)
d(50, 50)
d(0, 0)
# Out:
# line from 0.0, 0.0 to 0.0, 50.0, dist: 50.000
# 0.0, 16.7
# 0.0, 33.3
# 0.0, 50.0
# line from 0.0, 50.0 to 50.0, 50.0, dist: 50.000
# 16.7, 50.0
# 33.3, 50.0
# 50.0, 50.0
# line from 50.0, 50.0 to 50.0, 0.0, dist: 50.000
# 50.0, 33.3
# 50.0, 16.7
# 50.0, -0.0
# line from 50.0, -0.0 to 0.0, 0.0, dist: 50.000
# 33.3, -0.0
# 16.7, -0.0
# -0.0, -0.0
# line from -0.0, -0.0 to 50.0, 50.0, dist: 70.711
# 12.5, 12.5
# 25.0, 25.0
# 37.5, 37.5
# 50.0, 50.0
# line from 50.0, 50.0 to 0.0, 0.0, dist: 70.711
# 37.5, 37.5
# 25.0, 25.0
# 12.5, 12.5
# 0.0, 0.0
